# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# get dataset
df = pd.read_csv('C:/Users/behem/Downloads/Columbia.csv', index_col=0)

# %%
# top x rows
x = 100
df.head(x)
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# ...            ...    ...         ...       ...          ...   ...       ...
# 1068575    1303001  15300   60 months     22.06       423.10     F        F4
# 1049528    1280928  12800   60 months     11.71       282.86     B        B3
# 1068542    1303143  17500   60 months     17.27       437.47     D        D3
# 1068350    1302971   3500   36 months      6.03       106.53     A        A1
# 1067874    1302235   6000   60 months     12.69       135.57     B        B5
#
# ...

# %%
# columns
df.columns
# Out:
# Index(['member_id', 'CLI', 'term', 'int_rate', 'installment', 'grade',
#        'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'loan_status', 'pymnt_plan', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
# ...

# %%
# 
df.count()
# Out:
# member_id           100
# CLI                 100
# term                100
# int_rate            100
# installment         100
#                    ...
# all_util              0
# total_rev_hi_lim      0
# inq_fi                0
# total_cu_tl           0
# inq_last_12m          0
# Length: 69, dtype: int64

# %%
#shape of dataset
df.shape
# Out:
# (100, 69)

# %%
# find a specific 
df.query('`grade`.str.endswith("<ltr>")')
# Out:
# Empty DataFrame
# Columns: [member_id, CLI, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, loan_status, pymnt_plan, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, inq_last_6mths, mths_since_last_delinq, mths_since_last_record, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, next_pymnt_d, last_credit_pull_d, collections_12_mths_ex_med, mths_since_last_major_derog, policy_code, application_type, annual_inc_joint, dti_joint, verification_status_joint, acc_now_delinq, tot_coll_amt, tot_cur_bal, open_acc_6m, open_il_6m, open_il_12m, open_il_24m, mths_since_rcnt_il, total_bal_il, il_util, open_rv_12m, open_rv_24m, max_bal_bc, all_util, total_rev_hi_lim, inq_fi, total_cu_tl, inq_last_12m]
# ...

# %%
# count all values in grade column
df['grade'].value_counts()
# Out:
# B    39
# C    20
# A    17
# D    15
# E     5
# F     4
# Name: grade, dtype: int64

# %%
# count all values in term column
df['term'].value_counts()
# Out:
#  36 months    71
#  60 months    29
# Name: term, dtype: int64

# %%
# get everything in cli column greater than 20000
df[df['CLI']>20000]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1069740    1284848  20250   60 months     15.27       484.63     C        C4
# 1039153    1269083  21000   36 months     12.42       701.73     B        B4
# 1069539    1304608  31825   36 months      7.90       995.82     A        A4
# 1068120    1302485  25600   36 months      9.91       824.96     B        B1
# 1069410    1303652  21000   60 months     19.91       555.33     E        E4
# 1068994    1303432  22075   60 months     17.27       551.84     D        D3
#
#                                   emp_title emp_length home_ownership  ...  \
# id                                                                     ...
# 1069740    Archdiocese of Galveston Houston    3 years           RENT  ...
# 1039153                      Osram Sylvania  10+ years           RENT  ...
# 1069539  Audubon Mutual Housing Corporation    5 years       MORTGAGE  ...
# ...

# %%
# locate function, filters by labels
df.loc[:, ['CLI', 'term', 'grade']]
# Out:
#            CLI        term grade
# id
# 1077501   5000   36 months     B
# 1077430   2500   60 months     C
# 1077175   2400   36 months     C
# 1076863  10000   36 months     C
# 1075358   3000   60 months     B
# ...        ...         ...   ...
# 1068575  15300   60 months     F
# 1049528  12800   60 months     B
# 1068542  17500   60 months     D
# 1068350   3500   36 months     A
# 1067874   6000   60 months     B
#
# [100 rows x 3 columns]

# %%
df.loc[:, 'CLI':'loan_status']
# Out:
#            CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501   5000   36 months     10.65       162.87     B        B2
# 1077430   2500   60 months     15.27        59.83     C        C4
# 1077175   2400   36 months     15.96        84.33     C        C5
# 1076863  10000   36 months     13.49       339.31     C        C1
# 1075358   3000   60 months     12.69        67.79     B        B5
# ...        ...         ...       ...          ...   ...       ...
# 1068575  15300   60 months     22.06       423.10     F        F4
# 1049528  12800   60 months     11.71       282.86     B        B3
# 1068542  17500   60 months     17.27       437.47     D        D3
# 1068350   3500   36 months      6.03       106.53     A        A1
# 1067874   6000   60 months     12.69       135.57     B        B5
#
#                               emp_title emp_length home_ownership  annual_inc  \
# id
# 1077501                             NaN  10+ years           RENT     24000.0
# ...

# %%
df.loc[:, ['CLI', 'loan_status']]
# Out:
#            CLI  loan_status
# id
# 1077501   5000   Fully Paid
# 1077430   2500  Charged Off
# 1077175   2400   Fully Paid
# 1076863  10000   Fully Paid
# 1075358   3000      Current
# ...        ...          ...
# 1068575  15300      Current
# 1049528  12800   Fully Paid
# 1068542  17500  Charged Off
# 1068350   3500   Fully Paid
# 1067874   6000      Current
#
# [100 rows x 2 columns]

# %%
df.query('`grade`.str.endswith("F")')
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1071795    1306957   5600   60 months     21.28       152.39     F        F2
# 1068906    1303528   8200   60 months     21.28       223.14     F        F2
# 1068416    1302799   7200   60 months     21.67       197.51     F        F3
# 1068575    1303001  15300   60 months     22.06       423.10     F        F4
#
#                          emp_title emp_length home_ownership  ...  \
# id                                                            ...
# 1071795                        NaN    4 years            OWN  ...
# 1068906                   autozone    4 years           RENT  ...
# 1068416  Cross Country Travel Corp   < 1 year           RENT  ...
# 1068575                       OSSI    6 years           RENT  ...
#
#          total_bal_il il_util open_rv_12m open_rv_24m max_bal_bc all_util  \
# id
# 1071795           NaN     NaN         NaN         NaN        NaN      NaN
# ...

# %%
df.iloc[:, 0:5]
# Out:
#          member_id    CLI        term  int_rate  installment
# id
# 1077501    1296599   5000   36 months     10.65       162.87
# 1077430    1314167   2500   60 months     15.27        59.83
# 1077175    1313524   2400   36 months     15.96        84.33
# 1076863    1277178  10000   36 months     13.49       339.31
# 1075358    1311748   3000   60 months     12.69        67.79
# ...            ...    ...         ...       ...          ...
# 1068575    1303001  15300   60 months     22.06       423.10
# 1049528    1280928  12800   60 months     11.71       282.86
# 1068542    1303143  17500   60 months     17.27       437.47
# 1068350    1302971   3500   36 months      6.03       106.53
# 1067874    1302235   6000   60 months     12.69       135.57
#
# [100 rows x 5 columns]

# %%
df.iloc[:, [4, 6, 7]]
# Out:
#          installment sub_grade                       emp_title
# id
# 1077501       162.87        B2                             NaN
# 1077430        59.83        C4                           Ryder
# 1077175        84.33        C5                             NaN
# 1076863       339.31        C1             AIR RESOURCES BOARD
# 1075358        67.79        B5        University Medical Group
# ...              ...       ...                             ...
# 1068575       423.10        F4                            OSSI
# 1049528       282.86        B3                NCS Technologies
# 1068542       437.47        D3             Travelers Insurance
# 1068350       106.53        A1                   J&J Steel Inc
# 1067874       135.57        B5  Anadarko Petroleum Corporation
#
# [100 rows x 3 columns]

# %%
# columns 50-60, rows 1-10
df.iloc[50:60,1:10]
# Out:
#            CLI        term  int_rate  installment grade sub_grade  \
# id
# 1069248  15000   36 months      9.91       483.38     B        B1
# 1068120  25600   36 months      9.91       824.96     B        B1
# 1069244   7000   36 months     10.65       228.02     B        B2
# 1069243  12000   36 months     15.96       421.65     C        C5
# 1069238  12000   36 months      9.91       386.70     B        B1
# 1069410  21000   60 months     19.91       555.33     E        E4
# 1068409  16000   60 months     19.91       423.11     E        E4
# 1068487  10000   36 months     12.42       334.16     B        B4
# 1043961  10000   36 months     10.65       325.74     B        B2
# 1068945   7100   36 months     16.77       252.33     D        D2
#
#                      emp_title emp_length home_ownership
# id
# 1069248       Caterpillar Inc.    8 years       MORTGAGE
# 1068120  City of Santa Monica     9 years           RENT
# 1069244     Aerotek Scientific   < 1 year           RENT
# ...

# %%
df.groupby('grade').count()
# Out:
#        member_id  CLI  term  int_rate  installment  sub_grade  emp_title  \
# grade
# A             17   17    17        17           17         17         16
# B             39   39    39        39           39         39         38
# C             20   20    20        20           20         20         19
# D             15   15    15        15           15         15         13
# E              5    5     5         5            5          5          5
# F              4    4     4         4            4          4          3
#
#        emp_length  home_ownership  annual_inc  ...  total_bal_il  il_util  \
# grade                                          ...
# A              17              17          17  ...             0        0
# B              39              39          39  ...             0        0
# C              20              20          20  ...             0        0
# D              15              15          15  ...             0        0
# ...

# %%
df.sort_values(by='CLI')
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1069759    1304871   1000   36 months     16.29        35.31     D        D1
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1069866    1304956   3000   36 months      9.91        96.68     B        B1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# ...            ...    ...         ...       ...          ...   ...       ...
# 1039153    1269083  21000   36 months     12.42       701.73     B        B4
# 1069410    1303652  21000   60 months     19.91       555.33     E        E4
# 1068994    1303432  22075   60 months     17.27       551.84     D        D3
# 1068120    1302485  25600   36 months      9.91       824.96     B        B1
# 1069539    1304608  31825   36 months      7.90       995.82     A        A4
#
# ...

# %%
df.sort_values(by='int_rate', ascending=False)
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1068575    1303001  15300   60 months     22.06       423.10     F        F4
# 1068416    1302799   7200   60 months     21.67       197.51     F        F3
# 1068906    1303528   8200   60 months     21.28       223.14     F        F2
# 1071795    1306957   5600   60 months     21.28       152.39     F        F2
# 1048390    1279714  18000   60 months     19.91       475.99     E        E4
# ...            ...    ...         ...       ...          ...   ...       ...
# 1069469    1304526   6000   36 months      6.03       182.62     A        A1
# 1069742    1304855   9200   36 months      6.03       280.01     A        A1
# 1069971    1304884   3600   36 months      6.03       109.57     A        A1
# 1068967    1303403   4500   36 months      6.03       136.96     A        A1
# 1068350    1302971   3500   36 months      6.03       106.53     A        A1
#
# ...

# %%
df.groupby('grade')['CLI'].max()
# Out:
# grade
# A    31825
# B    25600
# C    20250
# D    22075
# E    21000
# F    15300
# Name: CLI, dtype: int64

# %%
df.groupby('sub_grade')['int_rate'].max()
# Out:
# sub_grade
# A1     6.03
# A2     6.62
# A3     7.51
# A4     7.90
# A5     8.90
# B1     9.91
# B2    10.65
# B3    11.71
# B4    12.42
# B5    12.69
# C1    13.49
# C2    14.27
# C3    14.65
# C4    15.27
# C5    15.96
# D1    16.29
# D2    16.77
# D3    17.27
# D4    17.58
# D5    18.25
# E1    18.64
# E3    19.42
# E4    19.91
# F2    21.28
# F3    21.67
# F4    22.06
# Name: int_rate, dtype: float64

# %%
df.groupby('sub_grade')['int_rate'].min()
# Out:
# sub_grade
# A1     6.03
# A2     6.62
# A3     7.51
# A4     7.90
# A5     8.90
# B1     9.91
# B2    10.65
# B3    11.71
# B4    12.42
# B5    12.69
# C1    13.49
# C2    14.27
# C3    14.65
# C4    15.27
# C5    15.96
# D1    16.29
# D2    16.77
# D3    17.27
# D4    17.58
# D5    18.25
# E1    18.64
# E3    19.42
# E4    19.91
# F2    21.28
# F3    21.67
# F4    22.06
# Name: int_rate, dtype: float64

# %%
df[df.CLI.between(20000, 40000)]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1069740    1284848  20250   60 months     15.27       484.63     C        C4
# 1039153    1269083  21000   36 months     12.42       701.73     B        B4
# 1069539    1304608  31825   36 months      7.90       995.82     A        A4
# 1068120    1302485  25600   36 months      9.91       824.96     B        B1
# 1069410    1303652  21000   60 months     19.91       555.33     E        E4
# 1068994    1303432  22075   60 months     17.27       551.84     D        D3
#
#                                   emp_title emp_length home_ownership  ...  \
# id                                                                     ...
# 1069740    Archdiocese of Galveston Houston    3 years           RENT  ...
# 1039153                      Osram Sylvania  10+ years           RENT  ...
# 1069539  Audubon Mutual Housing Corporation    5 years       MORTGAGE  ...
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# ...            ...    ...         ...       ...          ...   ...       ...
# 1068575    1303001  15300   60 months     22.06       423.10     F        F4
# 1049528    1280928  12800   60 months     11.71       282.86     B        B3
# 1068542    1303143  17500   60 months     17.27       437.47     D        D3
# 1068350    1302971   3500   36 months      6.03       106.53     A        A1
# 1067874    1302235   6000   60 months     12.69       135.57     B        B5
#
# ...

# %%
df.rename({'collections_12_mths_ex_med': '# of collections', 'acc_now_delinq': 'Delinquency'}, axis='columns')
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1077501    1296599   5000   36 months     10.65       162.87     B        B2
# 1077430    1314167   2500   60 months     15.27        59.83     C        C4
# 1077175    1313524   2400   36 months     15.96        84.33     C        C5
# 1076863    1277178  10000   36 months     13.49       339.31     C        C1
# 1075358    1311748   3000   60 months     12.69        67.79     B        B5
# ...            ...    ...         ...       ...          ...   ...       ...
# 1068575    1303001  15300   60 months     22.06       423.10     F        F4
# 1049528    1280928  12800   60 months     11.71       282.86     B        B3
# 1068542    1303143  17500   60 months     17.27       437.47     D        D3
# 1068350    1302971   3500   36 months      6.03       106.53     A        A1
# 1067874    1302235   6000   60 months     12.69       135.57     B        B5
#
# ...

# %%
# one-hot encoding
pd.get_dummies(df.grade)
# Out:
#          A  B  C  D  E  F
# id
# 1077501  0  1  0  0  0  0
# 1077430  0  0  1  0  0  0
# 1077175  0  0  1  0  0  0
# 1076863  0  0  1  0  0  0
# 1075358  0  1  0  0  0  0
# ...     .. .. .. .. .. ..
# 1068575  0  0  0  0  0  1
# 1049528  0  1  0  0  0  0
# 1068542  0  0  0  1  0  0
# 1068350  1  0  0  0  0  0
# 1067874  0  1  0  0  0  0
#
# [100 rows x 6 columns]

# %%
# I want to see all the loans which have ‘F’ grade.
df.query('`grade`.str.endswith("F")')
# Out:
#          member_id    CLI        term  int_rate  installment grade sub_grade  \
# id
# 1071795    1306957   5600   60 months     21.28       152.39     F        F2
# 1068906    1303528   8200   60 months     21.28       223.14     F        F2
# 1068416    1302799   7200   60 months     21.67       197.51     F        F3
# 1068575    1303001  15300   60 months     22.06       423.10     F        F4
#
#                          emp_title emp_length home_ownership  ...  \
# id                                                            ...
# 1071795                        NaN    4 years            OWN  ...
# 1068906                   autozone    4 years           RENT  ...
# 1068416  Cross Country Travel Corp   < 1 year           RENT  ...
# 1068575                       OSSI    6 years           RENT  ...
#
#          total_bal_il il_util open_rv_12m open_rv_24m max_bal_bc all_util  \
# id
# 1071795           NaN     NaN         NaN         NaN        NaN      NaN
# ...

# %%
# Filter rows from 50 to 100 and and 2,7,3 columns
df.iloc[50:100, [2, 7, 3]]
# Out:
#                term                        emp_title  int_rate
# id
# 1069248   36 months                 Caterpillar Inc.      9.91
# 1068120   36 months            City of Santa Monica       9.91
# 1069244   36 months               Aerotek Scientific     10.65
# 1069243   36 months            Chemat Technology Inc     15.96
# 1069238   36 months                    Scott & White      9.91
# 1069410   60 months                           Costco     19.91
# 1068409   60 months                  CA Technologies     19.91
# 1068487   36 months                          Netflix     12.42
# 1043961   36 months                             DCAA     10.65
# 1068945   36 months               Triple D security      16.77
# 1069142   60 months                           wrisco     12.69
# 1068934   60 months                              NaN     17.27
# 1069136   60 months                       webb candy     14.65
# 1068923   36 months                        Omniplex      16.77
# ...

# %%
# Find the  max CLI based on Term column……(maximum CLI $ given for each term)
df.groupby('term')['CLI'].max()
# Out:
# term
#  36 months    31825
#  60 months    22075
# Name: CLI, dtype: int64

# %%
# Find the  max CLI $ given for each loan Grade type   (A-F)
df.groupby('grade')['CLI'].max()
# Out:
# grade
# A    31825
# B    25600
# C    20250
# D    22075
# E    21000
# F    15300
# Name: CLI, dtype: int64

# %%
# Get the min CLI $ based on term and Grade 
print(df.groupby('term')['CLI'].min())
print(df.groupby('grade')['CLI'].min())
# Out:
# term
#  36 months    1000
#  60 months    2500
# Name: CLI, dtype: int64
# grade
# A    3500
# B    3000
# C    2400
# D    1000
# E    3000
# F    5600
# Name: CLI, dtype: int64

# %%
# Find the  max CLI $ each loan by Term, Grade type   (A-F) and Sub Grades (A1…..F4)
print(df.groupby('term')['CLI'].max())
print(df.groupby('grade')['CLI'].max())
print(df.groupby('sub_grade')['CLI'].max())
# Out:
# term
#  36 months    31825
#  60 months    22075
# Name: CLI, dtype: int64
# grade
# A    31825
# B    25600
# C    20250
# D    22075
# E    21000
# F    15300
# Name: CLI, dtype: int64
# sub_grade
# A1    10000
# A2    11000
# A3     9600
# A4    31825
# A5    14400
# B1    25600
# B2    12400
# B3    12800
# B4    21000
# B5    13000
# C1    12000
# C2    16425
# C3    17675
# C4    20250
# C5    12000
# D1    12000
# D2    12000
# D3    22075
# D4    13575
# D5     3000
# E1     3000
# E3     8200
# E4    21000
# F2     8200
# F3     7200
# F4    15300
# Name: CLI, dtype: int64

# %%
sns.scatterplot(x="dti", y="CLI", hue = 'term', data=df)
# Out:
# <AxesSubplot:xlabel='dti', ylabel='CLI'>

# %%
sns.boxplot(x="grade", y="CLI",data= df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='CLI'>

# %%
sns.violinplot(x='grade', y='CLI',data=df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='CLI'>

# %%
sns.catplot(x="annual_inc", y="CLI", hue="grade",col="term", data=df, palette = "rainbow")

# %%
sns.heatmap(df.corr(), fmt = ".8f")
# Out:
# <AxesSubplot:>
